# %%
# syntax error
print 'hello'
# Out:
#   File "/tmp/ipykernel_2088/2769809789.py", line 2
#     print 'hello'
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
# Indentation error
a = 5
if a==3:
print("hello")
# Out:
#   File "/tmp/ipykernel_2088/1394802657.py", line 4
#     print("hello")
#     ^
# IndentationError: expected an indented block after 'if' statement on line 3

# %%
# IndexError
# The IndexError is thrown when trying to access an item at an invalid index.
 l = [1,2,3]
 l[10]
# Out:
#   File "/tmp/ipykernel_2088/1826882505.py", line 3
#     l = [1,2,3]
#     ^
# IndentationError: unexpected indent

# %%
# ModuleNotFoundError
# The ModuleNotFoundError is thrown when a module could not be found.
import mathi
math.floor(5,3)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_2088/3879678651.py in <cell line: 0>()
# ----> 1 import mathi
#       2 math.floor(5,3)
#
# ModuleNotFoundError: No module named 'mathi'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# KeyError
# The KeyError is thrown when a key is not found
d = {'name':'chirag'}
d['age']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_2088/2206232787.py in <cell line: 0>()
#       2 # The KeyError is thrown when a key is not found
#       3 d = {'name':'chirag'}
# ----> 4 d['age']
#
# KeyError: 'age'

# %%
# TypeError
# The TypeError is thrown when an operation or function is
# applied to an object of an inappropriate type.
1 + 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_2088/1960386604.py in <cell line: 0>()
#       2 # The TypeError is thrown when an operation or function is
#       3 # applied to an object of an inappropriate type.
# ----> 4 1 + 'a'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
# ValueError
# The ValueError is thrown when a function's argument is of an inappropriate type.
int('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2088/1016288878.py in <cell line: 0>()
#       1 # ValueError
#       2 # The ValueError is thrown when a function's argument is of an inappropriate type.
# ----> 3 int('a')
#
# ValueError: invalid literal for int() with base 10: 'a'

# %%
# NameError
# The NameError is thrown when an object could not be found.
print(l)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2088/2090029465.py in <cell line: 0>()
#       1 # NameError
#       2 # The NameError is thrown when an object could not be found.
# ----> 3 print(l)
#
# NameError: name 'l' is not defined

# %%
#Attribute error
L = [1,2,3]
L.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2088/1686794326.py in <cell line: 0>()
#       1 #Attribute error
#       2 L = [1,2,3]
# ----> 3 L.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
# Exception error
try:
  with open('file.txt', 'r') as f:
    print(f.read())
except:
  print('file not found')
# Out:
# file not found

# %%
# catching specific exceptions

try:
  print(5/0)
  print(m)
  with open('file.txt', 'r') as f:
    print(f.read())
except NameError:
  print('variable is not defined')
except FileNotFoundError:
  print('file not found')
except Exception as e:
  print(e)

# except Exception as e:
#   print(e.with_traceback)
# Out:
# division by zero

# %%
#Raise Exception
class Bank:
  def __init__(self, balance):
    self.balance = balance

  def withdraw(self, amount):
    if amount < 0:
      raise Exception('amount cannot be -ve')
    if self.balance < amount:
      raise Exception('Insufficient Balance')
    self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(-100000)
except Exception as e:
  print(e)
else:
  print(obj.balance)
# Out:
# amount cannot be -ve

# %%
#Custom Exception

class MyException(Exception):
  def __init__(self, message):
    print(message)

class Bank:
  def __init__(self, balance):
    self.balance = balance

  def withdraw(self, amount):
    if amount < 0:
      raise MyException('amount cannot be -ve')
    if self.balance < amount:
      raise MyException('Insufficient Balance')
    self.balance = self.balance - amount

obj = Bank(10000)
try:
  obj.withdraw(-100000)
except MyException as e:
  pass
else:
  print(obj.balance)
# Out:
# amount cannot be -ve

# %%
class SecruityError(Exception):
  def __init__(self, message):
    print(message)

  def logout(self):
    print('Logout')

class Google:

  def __init__(self, name, email, password, device):
    self.name = name
    self.email = email
    self.password = password
    self.device = device

  def login(self, email, password, device):
    if device != self.device:
      raise SecruityError('You are caught')
    if self.email == email and self.password == password:
      print('Welcome')
    else:
      print('login error')

obj = Google('chirag', 'chirag@gmail.com', 1234, 'android')

try:
  obj.login('chirag@gmail.com', 1234, 'androd')
except SecruityError as e:
  e.logout()
else:
  print(obj.name)
finally:
  print('Connection closed')
# Out:
# You are caught
# Logout
# Connection closed
