# %%
import os
import cv2

# %%
def image_data_reader(folder_path):
    for file in os.listdir(folder_path):
        f_array = cv2.imread(os.path.join(folder_path,file))
        yield f_array

gen = image_data_reader('C:/Users/dhani/dog')

next(gen)
next(gen)
# Out:
# array([[[197, 255, 252],
#         [198, 255, 252],
#         [200, 255, 252],
#         ...,
#         [ 35, 128,  13],
#         [ 38, 131,  16],
#         [ 41, 134,  19]],
#
#        [[198, 255, 252],
#         [198, 255, 252],
#         [202, 255, 252],
#         ...,
#         [ 36, 128,  15],
#         [ 41, 131,  18],
#         [ 43, 135,  22]],
#
#        [[201, 255, 253],
#         [201, 255, 253],
#         [203, 255, 253],
#         ...,
#         [ 38, 127,  17],
#         [ 43, 130,  20],
#         [ 45, 134,  24]],
#
#        ...,
#
#        [[ 49, 126,  28],
#         [ 47, 124,  26],
#         [ 49, 126,  28],
#         ...,
#         [ 63, 148,  66],
#         [ 53, 137,  55],
#         [ 44, 129,  47]],
#
#        [[ 55, 134,  31],
#         [ 52, 131,  28],
#         [ 51, 127,  25],
#         ...,
#         [ 57, 144,  54],
#         [ 47, 131,  42],
#         [ 36, 123,  33]],
#
#        [[ 58, 137,  28],
#         [ 62, 141,  32],
#         [ 59, 135,  27],
# ...
