# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("DailyDelhiClimateTest.csv")
df.head()
# Out:
#          date   meantemp   humidity  wind_speed  meanpressure
# 0  2017-01-01  15.913043  85.869565    2.743478     59.000000
# 1  2017-01-02  18.500000  77.222222    2.894444   1018.277778
# 2  2017-01-03  17.111111  81.888889    4.016667   1018.333333
# 3  2017-01-04  18.700000  70.050000    4.545000   1015.700000
# 4  2017-01-05  18.388889  74.944444    3.300000   1014.333333

# %%
plt.scatter(df['date'], df['meantemp'])

# %%
# def ewma(series, beta):
#     data = {}
#     data['val0'] = 0
#     num = len(series)
#     for i, temp in zip(range(1,num+1),series):
#         data['val'+str(i)] = beta*data['val'+str(i-1)] + (1-beta)*temp

#     return data

# def ewma(series, beta):
#     ewma_vals = []
#     prev = series[0]

#     for temp in series:
#         if prev == series[0]:
#             prev = (1-beta)*prev
#             ewma_vals.append(prev)
#             continue
#         prev = beta*prev + (1-beta)*temp
#         ewma_vals.append(prev)

#     return ewma_vals


def custom_ewma(series, beta, init=None):
    if not series:
        return []
    # Initialize EWMA value
    if init is None:
        prev = series[0]
    else:
        prev = init

    ewma_vals = []

    for x in series:
        # Classic EWMA update rule
        prev = beta * prev + (1 - beta) * x
        ewma_vals.append(prev)

    return ewma_vals

# %%
a = ewma(df.meantemp, 0.9)
x1 = df['meantemp'].ewm(alpha=0.1, adjust=False).mean()

# %%
plt.figure(figsize=(15,6))
plt.subplot(121)
plt.title('custom')
plt.scatter(df['date'], a)
plt.scatter(df['date'], df['meantemp'], color='black')

plt.subplot(122)
plt.title('pandas function')
plt.scatter(df['date'], x1)
plt.scatter(df['date'], df['meantemp'], color='black')

# %%
x1 = df['meantemp'].ewm(alpha=0.1, adjust=False).mean()

# %%
plt.scatter(df['date'], x1)
plt.scatter(df['date'], df['meantemp'], color='black')
