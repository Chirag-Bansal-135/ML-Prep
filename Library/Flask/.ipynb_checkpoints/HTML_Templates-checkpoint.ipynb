# %%
from flask import Flask, render_template

# %%
app = Flask(__name__)

@app.route("/")
def home():
    return render_template("Index.html")

# @app.route('/<name>')
# def cont(name):
#     return render_template('Index.html', content=name, r=43234)

@app.route('/<name>')
def cont1(name):
    return render_template('Index.html', content=["tim", "joe", "bill"])

if __name__ == '__main__':
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# 127.0.0.1 - - [21/Nov/2025 11:46:06] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [21/Nov/2025 11:46:11] "GET /hj HTTP/1.1" 200 -
